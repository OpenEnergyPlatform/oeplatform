# %% [markdown]
# <img src="http://193.175.187.164/static/OEP_logo_2_no_text.svg" alt="OpenEnergy Platform" height="100" width="100"  align="left"/>
# <img src="http://reiner-lemoine-institut.de//wp-content/uploads/2015/09/rlilogo.png" alt="RLI" height="100" width="100" align="right"/>
#
# # OpenEnergy Platform

# %%
__copyright__ = "Reiner Lemoine Institut"
__license__   = "GNU Affero General Public License Version 3 (AGPL-3.0)"
__url__       = "https://github.com/openego/data_processing/blob/master/LICENSE"
__author__    = "Ludee"

# %%
from IPython.core.display import HTML

import requests
import pandas as pd

# oedb
oep_url= 'http://oep.iks.cs.ovgu.de/'

# token
your_token = ''

# %%
# select data
schema = 'boundaries'
table = 'bkg_vg250_2_lan'
where = 'reference_date=2016-01-01'
column = 'column=id&column=gen&column=geom'
orderby = 'gen'

result = requests.get(oep_url+'/api/v0/schema/'+schema+'/tables/'+table+'/rows/?where='+where+'&'+column, )
result.status_code
# Out:
# 200

# %%
df = pd.DataFrame(result.json())
df
# Out:
#                              gen  \
# 0                       Saarland
# 1              Baden-Württemberg
# 2            Nordrhein-Westfalen
# 3                         Bremen
# 4                         Hessen
# 5                    Brandenburg
# 6                  Niedersachsen
# 7         Mecklenburg-Vorpommern
# 8                Rheinland-Pfalz
# 9                         Berlin
# 10  Baden-Württemberg (Bodensee)
# 11                        Bremen
# 12                       Sachsen
# 13                Sachsen-Anhalt
# 14                       Hamburg
# 15             Bayern (Bodensee)
# 16             Baden-Württemberg
# 17             Baden-Württemberg
# 18                     Thüringen
# 19                        Bayern
# 20                 Niedersachsen
# 21                       Hamburg
# 22            Schleswig-Holstein
# 23                 Niedersachsen
# 24            Schleswig-Holstein
# 25            Schleswig-Holstein
# 26        Mecklenburg-Vorpommern
# 27        Mecklenburg-Vorpommern
#
#                                                  geom  id
# 0   0106000000010000000103000000010000000209000091...   1
# 1   010600000005000000010300000002000000402A000028...   2
# 2   010600000005000000010300000001000000D82300002F...   3
# 3   01060000000400000001030000000100000062040000BE...   5
# 4   010600000002000000010300000001000000181E000001...   6
# 5   010600000004000000010300000002000000E02000002B...   7
# 6   010600000013000000010300000004000000DD36000087...   8
# 7   010600000040000000010300000001000000473C000015...   9
# 8   010600000001000000010300000001000000481C00001A...  10
# 9   01060000000100000001030000000100000065040000F1...  11
# 10  01060000000100000001030000000200000023050000AC...  12
# 11  01060000000100000001030000000100000093000000C1...  13
# 12  010600000001000000010300000001000000A724000051...  21
# 13  0106000000020000000103000000040000000B1D00009B...  22
# 14  0106000000050000000103000000010000008D05000062...  23
# 15  010600000001000000010300000001000000FF000000A4...  14
# 16  0106000000010000000103000000020000005C03000004...  15
# 17  01060000000400000001030000000100000028000000D0...  16
# 18  010600000001000000010300000002000000A51D000041...  31
# 19  010600000001000000010300000001000000BC4A000009...  33
# 20  010600000001000000010300000001000000050000005B...  34
# 21  0106000000020000000103000000010000000E01000022...  17
# 22  010600000015000000010300000001000000C5030000BA...  19
# 23  0106000000100000000103000000010000003600000018...  25
# 24  01060000001D000000010300000001000000EE31000050...  26
# 25  01060000002500000001030000000200000034090000DE...  27
# 26  01060000000300000001030000000100000006000000A4...  29
# 27  010600000020000000010300000002000000C104000010...  30
